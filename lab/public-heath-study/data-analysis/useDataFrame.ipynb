# %%
import pandas as pd
import numpy as np
from os import getcwd

# %%
pwd
# Out:
# '/lab/public-heath-study/data-analysis'

# %% [markdown]
# ## Question 1
# Donnez le résultat de votre calcul pour l'année 2013

# %%
pop=pd.read_csv("../data/fr_population.csv")
pop=pop[['Zone','Valeur','Code zone']]
pop['Valeur']=pop['Valeur']*1000
pop=pop.rename(columns={"Valeur":"population", "Zone":"pays", "Code zone":"zone"})
pop
# Out:
#                                        pays  population  zone
# 0                               Afghanistan    30552000     2
# 1                            Afrique du Sud    52776000   202
# 2                                   Albanie     3173000     3
# 3                                   Algérie    39208000     4
# 4                                 Allemagne    82727000    79
# ..                                      ...         ...   ...
# 170  Venezuela (République bolivarienne du)    30405000   236
# 171                                Viet Nam    91680000   237
# 172                                   Yémen    24407000   249
# 173                                  Zambie    14539000   251
# 174                                Zimbabwe    14150000   181
#
# [175 rows x 3 columns]

# %%
pop['population'].sum()
# Out:
# 8413993000

# %%
pop.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 170    False
# 171    False
# 172    False
# 173    False
# 174    False
# Length: 175, dtype: bool

# %%
pop.drop_duplicates(subset=['pays'], keep= False)
pop=pop.loc[pop['pays']!= 'Chine',:]
pop.shape
pop['population'].sum()
# Out:
# 6997326000

# %%
pop=pop.loc[pop['pays']!= 'Chine',:]

# %%
pop.shape
# Out:
# (174, 3)

# %%
pop['population'].sum()
# Out:
# 6997326000

# %% [markdown]
# ## Question 2
# Identifier les redondances

# %%
veg = pd.read_csv("../data/fr_vegetaux.csv")
veg
# Out:
#        Code Domaine                                            Domaine  \
# 0              FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 1              FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 2              FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 3              FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 4              FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# ...             ...                                                ...
# 104866         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 104867         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 104868         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 104869         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 104870         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
#
#         Code zone         Zone  Code Élément  \
# 0               2  Afghanistan          5511
# 1               2  Afghanistan          5611
# 2               2  Afghanistan          5072
# 3               2  Afghanistan          5301
# 4               2  Afghanistan          5527
# ...           ...          ...           ...
# 104866        181     Zimbabwe           674
# 104867        181     Zimbabwe           684
# 104868        181     Zimbabwe           664
# 104869        181     Zimbabwe           674
# 104870        181     Zimbabwe           684
#
#                                                   Élément  Code Produit  \
# 0                                              Production          2511
# 1                                 Importations - Quantité          2511
# 2                                      Variation de stock          2511
# 3                                Disponibilité intérieure          2511
# 4                                                Semences          2511
# ...                                                   ...           ...
# 104866  Disponibilité de protéines en quantité (g/pers...          2680
# 104867  Disponibilité de matière grasse en quantité (g...          2680
# 104868     Disponibilité alimentaire (Kcal/personne/jour)          2899
# 104869  Disponibilité de protéines en quantité (g/pers...          2899
# 104870  Disponibilité de matière grasse en quantité (g...          2899
#
#                       Produit  Code année  Année               Unité   Valeur  \
# 0                         Blé        2013   2013  Milliers de tonnes  5169.00
# 1                         Blé        2013   2013  Milliers de tonnes  1173.00
# 2                         Blé        2013   2013  Milliers de tonnes  -350.00
# 3                         Blé        2013   2013  Milliers de tonnes  5992.00
# 4                         Blé        2013   2013  Milliers de tonnes   322.00
# ...                       ...         ...    ...                 ...      ...
# 104866  Aliments pour enfants        2013   2013     g/personne/jour     0.00
# 104867  Aliments pour enfants        2013   2013     g/personne/jour     0.00
# 104868           Miscellanees        2013   2013  Kcal/personne/jour     2.00
# 104869           Miscellanees        2013   2013     g/personne/jour     0.07
# 104870           Miscellanees        2013   2013     g/personne/jour     0.03
#
#        Symbole Description du Symbole
# 0            S  Données standardisées
# 1            S  Données standardisées
# 2            S  Données standardisées
# 3            S  Données standardisées
# 4            S  Données standardisées
# ...        ...                    ...
# 104866      Fc        Donnée calculée
# 104867      Fc        Donnée calculée
# 104868      Fc        Donnée calculée
# 104869      Fc        Donnée calculée
# 104870      Fc        Donnée calculée
#
# [104871 rows x 14 columns]

# %%
ani = pd.read_csv("../data/fr_animaux.csv")
ani
# Out:
#       Code Domaine                                            Domaine  \
# 0             FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 1             FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 2             FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 3             FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 4             FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# ...            ...                                                ...
# 37161         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 37162         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 37163         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 37164         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 37165         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
#
#        Code zone         Zone  Code Élément  \
# 0              2  Afghanistan          5511
# 1              2  Afghanistan          5611
# 2              2  Afghanistan          5301
# 3              2  Afghanistan          5142
# 4              2  Afghanistan           645
# ...          ...          ...           ...
# 37161        181     Zimbabwe          5142
# 37162        181     Zimbabwe           645
# 37163        181     Zimbabwe           664
# 37164        181     Zimbabwe           674
# 37165        181     Zimbabwe           684
#
#                                                  Élément  Code Produit  \
# 0                                             Production          2731
# 1                                Importations - Quantité          2731
# 2                               Disponibilité intérieure          2731
# 3                                             Nourriture          2731
# 4      Disponibilité alimentaire en quantité (kg/pers...          2731
# ...                                                  ...           ...
# 37161                                         Nourriture          2775
# 37162  Disponibilité alimentaire en quantité (kg/pers...          2775
# 37163     Disponibilité alimentaire (Kcal/personne/jour)          2775
# 37164  Disponibilité de protéines en quantité (g/pers...          2775
# 37165  Disponibilité de matière grasse en quantité (g...          2775
#
#                   Produit  Code année  Année               Unité  Valeur  \
# 0        Viande de Bovins        2013   2013  Milliers de tonnes  134.00
# 1        Viande de Bovins        2013   2013  Milliers de tonnes    6.00
# 2        Viande de Bovins        2013   2013  Milliers de tonnes  140.00
# 3        Viande de Bovins        2013   2013  Milliers de tonnes  140.00
# 4        Viande de Bovins        2013   2013                  kg    4.59
# ...                   ...         ...    ...                 ...     ...
# 37161  Plantes Aquatiques        2013   2013  Milliers de tonnes    0.00
# 37162  Plantes Aquatiques        2013   2013                  kg    0.00
# 37163  Plantes Aquatiques        2013   2013  Kcal/personne/jour    0.00
# 37164  Plantes Aquatiques        2013   2013     g/personne/jour    0.00
# 37165  Plantes Aquatiques        2013   2013     g/personne/jour    0.00
#
#       Symbole Description du Symbole
# 0           S  Données standardisées
# 1           S  Données standardisées
# 2           S  Données standardisées
# 3           S  Données standardisées
# 4          Fc        Donnée calculée
# ...       ...                    ...
# 37161       S  Données standardisées
# 37162      Fc        Donnée calculée
# 37163      Fc        Donnée calculée
# 37164      Fc        Donnée calculée
# 37165      Fc        Donnée calculée
#
# [37166 rows x 14 columns]

# %%
# Ajout de la variable origin
ani["Origine"] = "animale"
veg["Origine"] = "vegetale"


# On regroupe veg et ani en un unique dataframe, via une union
temp = ani.append(veg)


# Suppression de ani et veg
del ani, veg


# Transformation de temp en table pivot
data = temp.pivot_table(index=["Zone","Produit","Code Produit","Origine"],
                        columns = ["Élément"], values=["Valeur"], aggfunc=sum)

data.columns = ['Aliments pour animaux', 'Autres Utilisations', 'Disponibilité alimentaire (Kcal/personne/jour)', 
                'Disponibilité alimentaire en quantité (kg/personne/an)', 
                'Disponibilité de matière grasse en quantité (g/personne/jour)', 
                'Disponibilité de protéines en quantité (g/personne/jour)', 'Disponibilité intérieure', 
                'Exportations - Quantité', 'Importations - Quantité', 'Nourriture', 'Pertes', 'Production', 
                'Semences', 'Traitement', 'Variation de stock']


dispo_alimentaire = data.reset_index()

#Nourriture = nouriture pour humain

dispo_alimentaire.head()
# Out:
#           Zone                Produit  Code Produit   Origine  \
# 0  Afghanistan       Abats Comestible          2736   animale
# 1  Afghanistan        Agrumes, Autres          2614  vegetale
# 2  Afghanistan  Aliments pour enfants          2680  vegetale
# 3  Afghanistan                 Ananas          2618  vegetale
# 4  Afghanistan                Bananes          2615  vegetale
#
#    Aliments pour animaux  Autres Utilisations  \
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                    NaN                  NaN
#
#    Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                                             5.0
# 1                                             1.0
# 2                                             1.0
# 3                                             0.0
# 4                                             4.0
#
#    Disponibilité alimentaire en quantité (kg/personne/an)  \
# 0                                               1.72
# 1                                               1.29
# 2                                               0.06
# 3                                               0.00
# 4                                               2.70
#
#    Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 0                                               0.20
# 1                                               0.01
# 2                                               0.01
# 3                                                NaN
# 4                                               0.02
#
#    Disponibilité de protéines en quantité (g/personne/jour)  \
# 0                                               0.77
# 1                                               0.02
# 2                                               0.03
# 3                                                NaN
# 4                                               0.05
#
#    Disponibilité intérieure  Exportations - Quantité  Importations - Quantité  \
# 0                      53.0                      NaN                      NaN
# 1                      41.0                      2.0                     40.0
# 2                       2.0                      NaN                      2.0
# 3                       0.0                      NaN                      0.0
# 4                      82.0                      NaN                     82.0
#
#    Nourriture  Pertes  Production  Semences  Traitement  Variation de stock
# 0        53.0     NaN        53.0       NaN         NaN                 NaN
# 1        39.0     2.0         3.0       NaN         NaN                 NaN
# 2         2.0     NaN         NaN       NaN         NaN                 NaN
# 3         0.0     NaN         NaN       NaN         NaN                 NaN
# 4        82.0     NaN         NaN       NaN         NaN                 NaN

# %%
listecolonne = ['Aliments pour animaux', 'Autres Utilisations', 'Disponibilité intérieure', 
                'Exportations - Quantité', 'Importations - Quantité', 'Nourriture', 'Pertes', 'Production', 
                'Semences', 'Traitement', 'Variation de stock']


for colonne in listecolonne :
    dispo_alimentaire[colonne] = dispo_alimentaire[colonne] * 1000000

# %% [markdown]
# ## Question 3
# Calculez (pour chaque pays et chaque produit) la disponibilité alimentaire en kcal puis en kg de protéines.

# %%
dispo_alimentaire=dispo_alimentaire.rename(columns={"Zone":"pays"})
dispo_alimentaire=dispo_alimentaire.merge(pop,on="pays")
dispo_alimentaire.head()
dispo_alimentaire['Dispokcal'] = dispo_alimentaire ['Disponibilité alimentaire (Kcal/personne/jour)']*dispo_alimentaire['population']*365
dispo_alimentaire.head()
dispo_alimentaire['Dispoperproteine']=dispo_alimentaire ['Disponibilité de protéines en quantité (g/personne/jour)']*dispo_alimentaire['population']*365/1000

dispo_alimentaire.head()
# Out:
#           pays                Produit  Code Produit   Origine  \
# 0  Afghanistan       Abats Comestible          2736   animale
# 1  Afghanistan        Agrumes, Autres          2614  vegetale
# 2  Afghanistan  Aliments pour enfants          2680  vegetale
# 3  Afghanistan                 Ananas          2618  vegetale
# 4  Afghanistan                Bananes          2615  vegetale
#
#    Aliments pour animaux  Autres Utilisations  \
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                    NaN                  NaN
#
#    Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                                             5.0
# 1                                             1.0
# 2                                             1.0
# 3                                             0.0
# 4                                             4.0
#
#    Disponibilité alimentaire en quantité (kg/personne/an)  \
# 0                                               1.72
# 1                                               1.29
# 2                                               0.06
# 3                                               0.00
# 4                                               2.70
#
#    Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 0                                               0.20
# 1                                               0.01
# 2                                               0.01
# 3                                                NaN
# 4                                               0.02
#
#    Disponibilité de protéines en quantité (g/personne/jour)  ...  \
# 0                                               0.77         ...
# 1                                               0.02         ...
# 2                                               0.03         ...
# 3                                                NaN         ...
# 4                                               0.05         ...
#
#    Variation de stock  population_x  zone_x     Dispokcal  Dispoperproteine  \
# 0                 NaN      30552000       2  5.575740e+10         8586639.6
# 1                 NaN      30552000       2  1.115148e+10          223029.6
# 2                 NaN      30552000       2  1.115148e+10          334544.4
# 3                 NaN      30552000       2  0.000000e+00               NaN
# 4                 NaN      30552000       2  4.460592e+10          557574.0
#
#    Ratioenergiepoid  population_y  zone_y  population  zone
# 0       1052.026415      30552000       2    30552000     2
# 1        285.935385      30552000       2    30552000     2
# 2       5575.740000      30552000       2    30552000     2
# 3               NaN      30552000       2    30552000     2
# 4        543.974634      30552000       2    30552000     2
#
# [5 rows x 28 columns]

# %%
dispo_alimentaire=dispo_alimentaire.merge(pop,on="pays")
dispo_alimentaire.head()

# %%
dispo_alimentaire['Dispokcal'] = dispo_alimentaire ['Disponibilité alimentaire (Kcal/personne/jour)']*pop['population']*365
dispo_alimentaire.head()

# %%
dispo_alimentaire['Dispoperproteine']=dispo_alimentaire ['Disponibilité de protéines en quantité (g/personne/jour)']*pop['population']*365/1000
dispo_alimentaire.head()

# %% [markdown]
# ## Question 4
# Calculez pour chaque produit le ratio energie/poids

# %%
dispo_alimentaire['Ratioenergiepoid']= dispo_alimentaire['Dispokcal'] / dispo_alimentaire ['Nourriture']
dispo_alimentaire['Ratioperproteine']= dispo_alimentaire['Dispoperproteine']/ dispo_alimentaire ['Nourriture']
dispo_alimentaire.head()
dispo_alimentaire = dispo_alimentaire.replace([np.inf, -np.inf],np.nan)
ratio =dispo_alimentaire.groupby ('Produit').mean()
ratio =ratio.reset_index()
ratio.head()
ratio =ratio[['Produit', 'Ratioenergiepoid', 'Ratioperproteine']]
ratio.loc[ratio['Produit'] == 'Oeufs',:]
ratio =ratio[['Produit', 'Ratioenergiepoid', 'Ratioperproteine']]
ratio.loc[ratio['Produit'] == 'Avoine',:]
# Out:
#   Produit  Ratioenergiepoid  Ratioperproteine
# 7  Avoine       1892.485132          0.081775

# %%
dispo_alimentaire = dispo_alimentaire.replace([np.inf, -np.inf],np.nan)
ratio =dispo_alimentaire.groupby ('Produit').mean()
ratio =ratio.reset_index()
ratio.head()

# %%
ratio =ratio[['Produit', 'Ratioenergiepoid', 'Ratioperproteine']]
ratio.loc[ratio['Produit'] == 'Oeufs',:]

# %% [markdown]
# la teneur en proteine de l'avoine

# %%
ratio =ratio[['Produit', 'Ratioenergiepoid', 'Ratioperproteine']]
ratio.loc[ratio['Produit'] == 'Avoine',:]

# %% [markdown]
# ## Question 5
# Citez 5 aliments parmi les 20 aliments les plus caloriques

# %%
ratio.sort_values (by = 'Ratioenergiepoid', ascending = False)

# %% [markdown]
# ## Question 6
# Calculez pour les produits végétaux la dispo interieur mondiale exprimé en kcal

# %%
dfvegetaux = dispo_alimentaire.loc[dispo_alimentaire['Origine'] == 'vegetale',:]
dfvegetaux.head()

# %%
dfvegetaux['dispointerieurKcal'] = dfvegetaux ['Disponibilité intérieure'] * dfvegetaux['Ratioenergiepoid']
dfvegetaux.head()

# %% [markdown]
# ## Question 7
# Combien d'humains pourraient être nourris si toute la disponibilité intérieur mondiale de produits végétaux était utilisé pour de la nourriture

# %% [markdown]
# En termes de calories sachant qu'en moyenne une personne a besoin de 2500 calories par jour

# %%
resp1 = dfvegetaux['dispointerieurKcal'].sum()/ 365 / 2500
KG_PROT_PER_CAPITA_PER_DAY = 62 * .9 * .001
dfvegetaux['dispointerieurprot'] = dfvegetaux ['Disponibilité intérieure'] * dfvegetaux ['Ratioperproteine']
dfvegetaux.head()
resp2 = dfvegetaux['dispointerieurprot'].sum()/KG_PROT_PER_CAPITA_PER_DAY
resp1

milliardDepersonneFood = format(round(repQ81/1000000000,2))

# %% [markdown]
# Ce qui represente en pourcentage

# %% [markdown]
# ## Question 8

# %%
q_kcal = dfvegetaux["dispointerieurKcal"].sum()
q_kgprot = dfvegetaux["dispointerieurprot"].sum()
quantity = pd.DataFrame({"kcal": q_kcal, "kgprot": q_kgprot}, index=[0])

quantity

# %%
NB_KCAL_PER_CAPITA_PER_DAY = 2500
repQ81 = quantity["kcal"] / NB_KCAL_PER_CAPITA_PER_DAY
repQ81Pourcent = format(round(repQ81/1000000000,2))

sumkcal = quantity["kcal"].sum();
billionsDeKCalGlobla = sumkcal / 1000000000000

# %%
KG_PROT_PER_CAPITA_PER_DAY = 62 * .9 * .001
repQ82 = quantity["kgprot"] / KG_PROT_PER_CAPITA_PER_DAY
repQ82Pourcent = format(round(repQ81/1000000000,2))

# %% [markdown]
# ## question 9

# %%
dispoG = dispo_alimentaire["Disponibilité de matière grasse en quantité (g/personne/jour)"].sum() + dispo_alimentaire['Disponibilité de protéines en quantité (g/personne/jour)'].sum() + (dispo_alimentaire['Disponibilité alimentaire en quantité (kg/personne/an)'].sum() * 1000) 
dispoKcal = dispo_alimentaire['Disponibilité alimentaire (Kcal/personne/jour)'].sum() * 1000000 * dispo_alimentaire["Ratioenergiepoid"]

quantityQ9 = pd.DataFrame({"kcal": dispoKcal, "kgprot": dispoG}, index=[0])


quantityQ9['kcal']

# %%
NB_KCAL_PER_CAPITA_PER_DAY = 2500
repQ91 = quantityQ9["kcal"] / NB_KCAL_PER_CAPITA_PER_DAY
repQ91Pourcent = format(round(repQ91/1000000000,2))

KG_PROT_PER_CAPITA_PER_DAY = 62 * .9 * .001
repQ92 = quantityQ9["kgprot"] / KG_PROT_PER_CAPITA_PER_DAY
repQ92Pourcent = format(round(repQ92/1000000000,2))

repQ91Pourcent

# %% [markdown]
# ## Question 10

# %%
sousAlimentationCsv = pd.read_csv("../data/fr_sousalimentation.csv")
sousAlimentationCsv
# Out:
#      Code Domaine                             Domaine  Code zone         Zone  \
# 0              FS  Données de la sécurité alimentaire          2  Afghanistan
# 1              FS  Données de la sécurité alimentaire          2  Afghanistan
# 2              FS  Données de la sécurité alimentaire          2  Afghanistan
# 3              FS  Données de la sécurité alimentaire          2  Afghanistan
# 4              FS  Données de la sécurité alimentaire          2  Afghanistan
# ...           ...                                 ...        ...          ...
# 1015           FS  Données de la sécurité alimentaire        181     Zimbabwe
# 1016           FS  Données de la sécurité alimentaire        181     Zimbabwe
# 1017           FS  Données de la sécurité alimentaire        181     Zimbabwe
# 1018           FS  Données de la sécurité alimentaire        181     Zimbabwe
# 1019           FS  Données de la sécurité alimentaire        181     Zimbabwe
#
#       Code Élément Élément  Code Produit  \
# 0             6132  Valeur        210011
# 1             6132  Valeur        210011
# 2             6132  Valeur        210011
# 3             6132  Valeur        210011
# 4             6132  Valeur        210011
# ...            ...     ...           ...
# 1015          6132  Valeur        210011
# 1016          6132  Valeur        210011
# 1017          6132  Valeur        210011
# 1018          6132  Valeur        210011
# 1019          6132  Valeur        210011
#
#                                                 Produit  Code année  \
# 0     Nombre de personnes sous-alimentées (millions)...    20122014
# 1     Nombre de personnes sous-alimentées (millions)...    20132015
# 2     Nombre de personnes sous-alimentées (millions)...    20142016
# 3     Nombre de personnes sous-alimentées (millions)...    20152017
# 4     Nombre de personnes sous-alimentées (millions)...    20162018
# ...                                                 ...         ...
# 1015  Nombre de personnes sous-alimentées (millions)...    20122014
# 1016  Nombre de personnes sous-alimentées (millions)...    20132015
# 1017  Nombre de personnes sous-alimentées (millions)...    20142016
# 1018  Nombre de personnes sous-alimentées (millions)...    20152017
# 1019  Nombre de personnes sous-alimentées (millions)...    20162018
#
#           Année     Unité Valeur Symbole Description du Symbole  Note
# 0     2012-2014  millions    7.9       F         Estimation FAO   NaN
# 1     2013-2015  millions    8.8       F         Estimation FAO   NaN
# 2     2014-2016  millions    9.6       F         Estimation FAO   NaN
# 3     2015-2017  millions   10.2       F         Estimation FAO   NaN
# 4     2016-2018  millions   10.6       F         Estimation FAO   NaN
# ...         ...       ...    ...     ...                    ...   ...
# 1015  2012-2014  millions    6.6       F         Estimation FAO   NaN
# 1016  2013-2015  millions    7.2       F         Estimation FAO   NaN
# 1017  2014-2016  millions    7.8       F         Estimation FAO   NaN
# 1018  2015-2017  millions    8.2       F         Estimation FAO   NaN
# 1019  2016-2018  millions    8.5       F         Estimation FAO   NaN
#
# [1020 rows x 15 columns]

# %%
ssAlim = pd.read_csv("../data/fr_sousalimentation.csv")
ssAlim = ssAlim[['Code année','Code zone','Zone','Produit','Valeur','Année']]
ssAlim["Valeur"] = pd.to_numeric(ssAlim["Valeur"],errors='coerce')
ssAlim['millionPersSsAlimenter'] = ssAlim['Valeur']
ssAlim = ssAlim.loc[(ssAlim['Code année'] == 20122014 )]
ssAlim = ssAlim.groupby(['Zone']).sum()
sumSsAlim = ssAlim['millionPersSsAlimenter'].sum()
sumSsAlim

# %%
sousAlimentationCsv = pd.read_csv("../data/fr_sousalimentation.csv")
sousAlimentationCsv=sousAlimentationCsv[['Code année','Code zone','Zone','Produit','Valeur','Année']]
sousAlimentationCsv["Valeur"] = pd.to_numeric(sousAlimentationCsv["Valeur"],errors='coerce')
sousAlimentationCsv['underfeed'] = sousAlimentationCsv['Valeur'] * 1000000
sousAlimentationCsv = sousAlimentationCsv.loc[(sousAlimentationCsv['Code année'] == 20122014 )]
sousAlimentationCsv = sousAlimentationCsv.groupby(['Zone']).sum()
sousAlimentationCsv

# %%
sousAlimentationCsv = sousAlimentationCsv.loc[(sousAlimentationCsv['Code année'] == 20122014 )]
sousAlimentationCsv = sousAlimentationCsv.groupby(['Zone']).sum()
sousAlimentationCsv

# %%
pop=pd.read_csv("../data/fr_population.csv")
pop=pop[['Zone','Valeur','Code zone']]
pop['Valeur']=pop['Valeur']*1000
pop=pop.rename(columns={"Valeur":"population", "Zone":"pays", "Code zone":"zone"})
pop

# %%
##
sousAlimentationPopulation = pd.merge(left=sousAlimentationCsv, right=pop, left_on='Code zone', right_on='zone')
sousAlimentationPopulation['ProportionSsAlimentPopulation'] = (sousAlimentationPopulation['underfeed'] * 100) / sousAlimentationPopulation['population']

## moyenne Pourcentage Mondial des personne sur une année

pourcentSousAlimentationWorld = (sousAlimentationPopulation['underfeed'].sum() * 100) / sousAlimentationPopulation['population'].sum()

sousAlimentationPopulation

# %% [markdown]
# ## Question 11

# %%
## http://www.fao.org/in-action/inpho/crop-compendium/cereals-grains/fr/?page=1&ipp=7&no_cache=1&tx_dynalist_pi1[par]=YToxOntzOjE6IkwiO3M6MToiMSI7fQ==

##Repérez dans vos données les informations concernant les céréales (par exemple en créant une colonne de type booléen nommée "is_cereal").

## : En ne prenant en compte que les céréales destinées à l'alimentation (humaine et animale), 
cerealsCsv = pd.read_csv("/Users/yassine/Desktop/data-python/fr_céréales.csv")

cerealsCsv['is_cereals'] = 'false'
cerealsCsv.loc[cerealsCsv['Produit'] == 'Maïs', ['is_cereals']] = 'true'
cerealsCsv.loc[cerealsCsv['Produit'] == 'Millet', ['is_cereals']] = 'true'
cerealsCsv.loc[cerealsCsv['Produit'] == 'Blé', ['is_cereals']] = 'true'
cerealsCsv.loc[cerealsCsv['Produit'] == 'Riz (Eq Blanchi)', ['is_cereals']] = 'true'
cerealsCsv.loc[cerealsCsv['Produit'] == 'Orge', ['is_cereals']] = 'true'
cerealsCsv.loc[cerealsCsv['Produit'] == 'Sorgho', ['is_cereals']] = 'true'
cerealsCsv = cerealsCsv.rename(columns={"Valeur":"populationSsAlimenter"})

cerealsCsv

# %%
cerealsCsv = cerealsCsv[['Code zone','Zone','Unité','populationSsAlimenter','Code Produit','is_cereals']]
cerealsCsv

# %%
daAnimal = dispo_alimentaire.loc[dispo_alimentaire['Origine'] == 'animale',:]
daAnimal['Aliments pour animaux'] = daAnimal['Aliments pour animaux'].astype(float)

# %%
animalCereal = pd.concat([daAnimal, cerealsCsv], axis=1, join='inner')
animalCereal
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-3cd1a25efc57> in <module>
# ----> 1 animalCereal = pd.concat([daAnimal, cerealsCsv], axis=1, join='inner')
#       2 animalCereal
#
# NameError: name 'daAnimal' is not defined

# %%
##En ne prenant en compte que les céréales destinées à l'alimentation (humaine et animale), 
##quelle proportion (en termes de poids) est destinée à l'alimentation animale 

isCereal = animalCereal.loc[animalCereal['is_cereals'] == 'true',:]
tchekValuesAnimalCereal = isCereal.loc[isCereal['Aliments pour animaux'] > 0,:]
sumAlimentPourAnimaux = tchekValuesAnimalCereal['Aliments pour animaux'].sum()
tchekValuesAnimalCereal['ProportionFoodAnimalsByGlobalFood'] = tchekValuesAnimalCereal['Nourriture'] /  (tchekValuesAnimalCereal['Nourriture'] + tchekValuesAnimalCereal['Aliments pour animaux'])
tchekValuesAnimalCereal

# %%
sumAlimentPourAnimaux

# %%
sumNourritues = tchekValuesAnimalCereal['Nourriture'].sum()
globalproportionFoodAnimalsByGlobalFood = sumNourritues /  (sumAlimentPourAnimaux + sumAlimentPourAnimaux)

globalproportionFoodAnimalsByGlobalFood

# %%
## Sélectionnez parmi les données des bilans alimentaires les informations .
## relatives aux pays dans lesquels la FAO recense des personnes en sous-nutrition


dispoSsAlimPop = pd.concat([dispo_alimentaire, sousAlimentationPopulation], axis=1, join='inner')

dispoSsAlimPop.columns

# %%
unsetImportationNoneValues = dispoSsAlimPop.loc[dispoSsAlimPop['Importations - Quantité'] > 0,:]
unsetImportationNoneValues.sort_values('Importations - Quantité')
unsetImportationNoneValues
importations = unsetImportationNoneValues[['Code zone','Zone','Produit','Importations - Quantité']]
rankImportations = importations.sort_values(by=['Importations - Quantité'], ascending=False)[:15]
rankImportations

# %%
##Parmi les données des bilans alimentaires au niveau mondial, sélectionnez 
##les 200 plus grandes importations de ces produits 
##(1 importation = une quantité d'un produit donné importée par un pays donné)

rankImportation200 = importations.sort_values(by=['Importations - Quantité'])[:200]

rankImportation200


##rep 

##imp = data[(data.item.isin(exported_products)) & (data.year == YEAR)]
##imp.sort_values("Import Quantity").iloc[200:,]

# %%
pd = rankImportation200.groupby("Produit")

pd

# %%
dispo_alimentaire.columns
dispo_alimentaire=dispo_alimentaire.rename(columns={"Zone":"zone"})

# %%
sousAlimentationPopulation

# %% [markdown]
# ## fin de la 11

# %% [markdown]
# ## Question 12

# %%
ratiodisp_inter = dispo_alimentaire[['produit', 'ratioDispoInterieur']].sort_values('ratioDispoInterieur', ascending=False)[:3]

ratioanim_hum = dispo_alimentaire[['produit', 'ratioAlimentPourAnimaux']].sort_values('ratioAlimentPourAnimaux', ascending=False)\[:3]

# %% [markdown]
# ## Question 13

# %%
qt_cere_pr_anim_ktonne = dispo_alimentaire.loc[
    (dispo_alimentaire.pays == "États-Unis d'Amérique")
    & (dispo_alimentaire.is_cereals == true),
    "alim_pr_anim__ktonne"
].sum()

qt_cere_pr_anim_ktonne

# %% [markdown]
# ## question 14

# %%
thailande = dispo_alimentaire.loc[
    (dispo_alimentaire'pays'] == 'Thaïlande')
    &(dispo_alimentaire['produit'] == 'Manioc'),
].iloc[0]

proportion_manioc_export = thailande['export__ktonne'] / thailande['prod__ktonne']
proportion_per_ss_alim = thailande['pop_ss_alim'] / sr['pop']

# %% [markdown]
# ## Calculer le nombre de personne qui serais nourris avec toute la disponibilté alimentaire

# %%
##calcule dispointerieurKcal =  (dispoKalorie / nourriture ) 
## somme de toute les calories 
resp1 = dfvegetaux['dispointerieurKcal'].sum() / 365 / 2500
milliardDepersonneFood = format(round(resp1/1000000000,2))

milliardDepersonneFood
milliardDepersonneFood = pd.to_numeric(milliardDepersonneFood, downcast='float')
milliardDepersonneFood
# Out:
# 13.49

# %%
dispoAlimentaireMondial

# %%
sumPop = pop['population'].sum()
millardPop  = format(round(sumPop/1000000000,2))
millardPop = pd.to_numeric(millardPop, downcast='float')
millardPop
# Out:
# 7.0

# %%
raisePopVegetauxFood = (milliardDepersonneFood - millardPop) / milliardDepersonneFood * 100

raisePopVegetauxFood
# Out:
# 48.10971021652222

# %%
cereals = pd.read_csv("../data/fr_cereales.csv")
cereals
